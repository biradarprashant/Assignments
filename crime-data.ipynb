# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering

# %%
crimedata=pd.read_csv("D:/Excelr-Class/CSV/crime_data.csv")

# %%
crimedata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
# Unnamed: 0    50 non-null object
# Murder        50 non-null float64
# Assault       50 non-null int64
# UrbanPop      50 non-null int64
# Rape          50 non-null float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 2.0+ KB

# %%
crimedata.dtypes
# Out:
# Unnamed: 0     object
# Murder        float64
# Assault         int64
# UrbanPop        int64
# Rape          float64
# dtype: object

# %%
def norm_func(i):
    X = (i-i.min()/i.max()-i.min())
    return X

# %%
df_norm=norm_func(crimedata.iloc[:,1:])
df_norm
# Out:
#        Murder     Assault   UrbanPop       Rape
# 0   12.354023  190.866469  25.648352  13.741304
# 1    9.154023  217.866469  15.648352  37.041304
# 2    7.254023  248.866469  47.648352  23.541304
# 3    7.954023  144.866469  17.648352  12.041304
# 4    8.154023  230.866469  58.648352  33.141304
# 5    7.054023  158.866469  45.648352  31.241304
# 6    2.454023   64.866469  44.648352   3.641304
# 7    5.054023  192.866469  39.648352   8.341304
# 8   14.554023  289.866469  47.648352  24.441304
# 9   16.554023  165.866469  27.648352  18.341304
# 10   4.454023    0.866469  50.648352  12.741304
# 11   1.754023   74.866469  21.648352   6.741304
# 12   9.554023  203.866469  50.648352  16.541304
# 13   6.354023   67.866469  32.648352  13.541304
# 14   1.354023   10.866469  24.648352   3.841304
# 15   5.154023   69.866469  33.648352  10.541304
# 16   8.854023   63.866469  19.648352   8.841304
# 17  14.554023  203.866469  33.648352  14.741304
# 18   1.254023   37.866469  18.648352   0.341304
# 19  10.454023  254.866469  34.648352  20.341304
# 20   3.554023  103.866469  52.648352   8.841304
# 21  11.254023  209.866469  41.648352  27.641304
# 22   1.854023   26.866469  33.648352   7.441304
# 23  15.254023  213.866469  11.648352   9.641304
# 24   8.154023  132.866469  37.648352  20.741304
# 25   5.154023   63.866469  20.648352   8.941304
# 26   3.454023   56.866469  29.648352   9.041304
# 27  11.354023  206.866469  48.648352  38.541304
# 28   1.254023   11.866469  23.648352   2.041304
# 29   6.554023  113.866469  56.648352  11.341304
# 30  10.554023  239.866469  37.648352  24.641304
# 31  10.254023  208.866469  53.648352  18.641304
# 32  12.154023  291.866469  12.648352   8.641304
# 33  -0.045977   -0.133531  11.648352  -0.158696
# 34   6.454023   74.866469  42.648352  13.941304
# 35   5.754023  105.866469  35.648352  12.541304
# 36   4.054023  113.866469  34.648352  21.841304
# 37   5.454023   60.866469  39.648352   7.441304
# 38   2.554023  128.866469  54.648352   0.841304
# 39  13.554023  233.866469  15.648352  15.041304
# 40   2.954023   40.866469  12.648352   5.341304
# 41  12.354023  142.866469  26.648352  19.441304
# 42  11.854023  155.866469  47.648352  18.041304
# 43   2.354023   74.866469  47.648352  15.441304
# 44   1.354023    2.866469  -0.351648   3.741304
# 45   7.654023  110.866469  30.648352  13.241304
# 46   3.154023   99.866469  40.648352  18.741304
# 47   4.854023   35.866469   6.648352   1.841304
# 48   1.754023    7.866469  33.648352   3.341304
# 49   5.954023  115.866469  27.648352   8.141304

# %%
dendrogram=sch.dendrogram(sch.linkage(df_norm,method='single'))

# %%
hc=AgglomerativeClustering(n_clusters=4,
                          affinity='euclidean',
                          linkage='average')
hc
# Out:
# AgglomerativeClustering(affinity='euclidean', compute_full_tree='auto',
#             connectivity=None, linkage='average', memory=None,
#             n_clusters=4,
#             pooling_func=<function mean at 0x000002B6BB328598>)

# %%
y_hc = hc.fit_predict(df_norm)
Clusters=pd.DataFrame(y_hc,columns=['Clusters'])

# %%
df_norm['h_clusterid'] = h_clusters.labels_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-05ec57e7e798> in <module>()
# ----> 1 df_norm['h_clusterid'] = h_clusters.labels_
#
# NameError: name 'h_clusters' is not defined
